# %% [markdown]
# ![1_Roadmap.png](attachment:1_Roadmap.png)

# %%
# basic libraries

# %%
# reading the dataset

# %%
#Descriptive analysis
"""
size
info
describe
head
tail
set pd column

"""

# %%
# missing value
# capping input approach mean median mode
# drop approach

# %%
#scaling 
# standardscaling 
# minmax scaling

# %%
# outlier treatment
# boxplot
# trimming approach
#capping approach
#IQR
#ZSCORE

# %%
#encoding

# %%
# corr
# heatmap

# %%
# X Y 
# TRAIN TEST SPLIT STRATIFY

# %%
# cross validation

# %%
# BALANCING APPROACH  UNDERFITTING OVER FITTING SMOTE

# %%
# IMPORT THE ALGORITHM
# FOR REGRESSION
# LINEAR REGRESSION
#RANDOM FOREST REGRESSION
#dT regression
#knn
#svr

# %%
#Lasso, Ridge,elastic net

# %%
# regression model evaluation  mean square erroe, r2 score

# %%
# ols concept STATSMODEL FAMILY # R2 . ADJ R2..

# %%
# VIF #STATSMODEL FAMILY# ADDING CONSTATNT IS REQUIRED

# %%
#for classification
# logoistic
# DT
# RF classifier
#knn
#SVC
#

# %%
# classification model evaluation Confusion matrix, CLASSIFICATION REPORT, RECALL PRECISION..
# ROC AUC CURVE

# %%
# FOR KNN HOW TO DROW GRAPH

# %%
# FOR KMEANS HOW TO DRAW GRAPH

# %%
#PCA ALGOM

# %%
#ensemble learning DT, VOTING,BAGGING,BOOSTING XG BOOST ADA BOOST

# %%
# HYPERPARAMETER TUNNING---- Param_grid,model/algo

# RANDOM SEARCH CV
#GRID SEARCH CV

# %%
# UNSUPERVISED ML
#MEANS
